# %%
import numpy as np
import pandas as pd

X_train_con_outliers = pd.read_excel("/workspaces/Tulio-Gimenez-Tutorial-del-Proyecto-Arbol-de-Decision/data/processed/X_train_con_outliers.xlsx")

X_train_con_outliers.head()

y_train = pd.read_excel("/workspaces/Tulio-Gimenez-Tutorial-del-Proyecto-Arbol-de-Decision/data/processed/y_train.xlsx")

y_train.head()

X_train_sin_outliers = pd.read_excel("/workspaces/Tulio-Gimenez-Tutorial-del-Proyecto-Arbol-de-Decision/data/processed/X_train_sin_outliers.xlsx")

X_train_sin_outliers.head()
# Out:
#    Pregnancies  Glucose  DiabetesPedigreeFunction   Age  BloodPressure  \
# 0          2.0     84.0                     0.304  21.0             35
# 1          9.0    112.0                     1.200  50.0             82
# 2          1.0    139.0                     0.654  22.0             46
# 3          0.0    161.0                     0.254  65.0             50
# 4          6.0    134.0                     0.238  46.0             80
#
#    SkinThickness  Insulin    BMI
# 0              0    0.000  13.35
# 1             24    0.000  28.20
# 2             19   83.000  28.70
# 3              0    0.000  21.90
# 4             37  318.125  46.20

# %%
X_train_con_outliers.head()
# Out:
#    Pregnancies  Glucose  DiabetesPedigreeFunction  Age  BloodPressure  \
# 0            2       84                     0.304   21              0
# 1            9      112                     1.282   50             82
# 2            1      139                     0.654   22             46
# 3            0      161                     0.254   65             50
# 4            6      134                     0.238   46             80
#
#    SkinThickness  Insulin   BMI
# 0              0        0   0.0
# 1             24        0  28.2
# 2             19       83  28.7
# 3              0        0  21.9
# 4             37      370  46.2

# %%
X_train_con_outliers.shape
# Out:
# (614, 8)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

accuracy_results = []
#results = []
models = []
for dataset in [
    X_train_con_outliers,
    X_train_sin_outliers
    
]:
  
    model = DecisionTreeClassifier(random_state=42)

    model.fit(dataset, y_train)
    y_pred = model.predict(dataset)
    accuracy = accuracy_score(y_train, y_pred)
    accuracy_results.append(accuracy_score(y_train, y_pred))

print("Accuracy:", accuracy_results)
print("Mejor Accuracy:", max(accuracy_results))
# Out:
# Accuracy: [1.0, 1.0]
# Mejor Accuracy: 1.0
